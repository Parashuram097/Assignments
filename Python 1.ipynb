# %% [markdown]
# ![Python%201.png](attachment:Python%201.png)

# %%
"""Q1. Who developed Python programming language?"""
# Guido van Rossum
# Out:
# 'Q1. Who developed Python programming language?'

# %%
"""Q2. Which type of programming does python support?"""
# Python is object oriented programming language.
# Out:
# 'Q2. Which type of programming does python support?'

# %%
"""Q3. is python case sensitive when dealing with identifiers?"""
# yes python is case sensitive programming language.
# Out:
# 'Q3. is python case sensitive when dealing with identifiers?'

# %%
"""Q4. what is the correct extension of the python file?"""
# .py is the correct extension of python file.
# Out:
# 'Q4. what is the correct extension of the python language?'

# %%
"""Q5. is Python code compiled or interpreted?"""
# Python is interpreted language.
# Out:
# 'Q5. is Python code compiled or interpreted?'

# %%
"""Q6. name a few blocks of code used to define in python language?"""
"""def abc():
    print(0)
    if else
    etc....
    """
# Out:
# 'Q6. name a few blocks of code used to define in python language?'

# %%
"""Q7.state a character used to give single line comments in python?"""
"""  # is used for single line comment in python  """
# Out:
# 'Q7.state a character used to give single line comments in python?'

# %%
"""Q8. Mention functions which can help us to find the version of python that we are currently working on?"""
#  __version__()
import sys
print(sys.version)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]

# %%
"""Q9. python supports the creation of ananymous functions at runtime,using a construct called ________"""
# Lambda function
# Out:
# 'Q9. python supports the creation of ananymous functions at runtime,using a construct called ________'

# %%
"""Q10. what does pip stands for?"""
# pip installs packages
# Out:
# 'Q10. what does pip stands for?'

# %%
"""Q11. mention a few build-in functions in python?"""

# print(),len(),range(),str(),input()  etc....
# Out:
# 'Q11. mention a few build-in functions in python?'

# %%
"""Q12. what is the maximum possible length of an identifier in Pytohn?"""
# 79 characters
# Out:
# 'Q12. what is the maximum possible length of an identifier in Pytohn?'

# %%
"""Q13. What are the benefits of using Python?"""
# simple and easy to code,lot of opensource packages for data science like pandas,numpy
# Out:
# 'Q13. What are the benefits of using Python?'

# %%
"""Q14.How is memory managed in Python?"""
# Python handles it on it's own using cyclic gargabe collection
# Out:
# 'Q14.How is memory managed in Python?'

# %%
"""Q15. How to install Python on Windows and set path variables?"""
# Out:
# 'Q15. How to install Python on Windows and set path variables?'

# %%
"""Q16. is indentation required in Python?"""
# yes indentation required in Python because we don't use {} in Python
# Out:
# 'Q16. is indentation required in Python?'
