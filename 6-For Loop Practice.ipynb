# %% [markdown]
# ![6-For%20Loop%20Practice.png](attachment:6-For%20Loop%20Practice.png)

# %%
"""Q1. Explain with an example each when to use a for loop and a while loop"""

""" we can for loop when we know the number of itaration and while loop can be used when we don't the number of iteration 
ex....live video capturing from camera can be used in while loop"""

#for loop

for i in range(10):
    print(i)

def log()
    while True:
        import logging
        logging.basicConfig(filename="text.log",level=logging.INFO)

# %%
"""Q2. Write a python program to print the sum and product of the first 10 natural numbers using for
and while loop."""

result1=0
for i in range(11):
    result1+=i
print(result1)


a=0
result2=0
while a<=10:
    result2+=a
    a+=1

print(result2)
# Out:
# 55
# 55

# %%
"""Q3. Create a python program to compute the electricity bill for a household.
The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.


You are required to take the units of electricity consumed in a month from the user as input.


Your program must pass this test case: when the unit of electricity consumed by the user in a month is
310, the total electricity bill should be 2250."""

units = int(input("Enter the number of units consumed: "))
total_bill = 0

if units <= 100:
    total_bill = units * 4.5
elif units <= 200:
    total_bill = 100 * 4.5 + (units - 100) * 6
elif units <= 300:
    total_bill = 100 * 4.5 + 100 * 6 + (units - 200) * 10
else:
    total_bill = 100 * 4.5 + 100 * 6 + 100 * 10 + (units - 300) * 20

print("Total electricity bill: Rs.", total_bill)
# Out:
# Enter the number of units consumed: 310
# Total electricity bill: Rs. 2250.0

# %%
"""Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
that list."""

l1=[i for i in range(1,101,1)]
l2=[]
l3=[]

for i in l1:
    if(i**3)%4==0 or (i**3)%5==0:
        l2.append(i)

i=0
while i<100:
    if(l1[i]**3)%4==0 or (l1[i]**3)%5==0:
        l3.append(l1[i])
    i+=1
    
print(l2)
print(l3)
# Out:
# [2, 4, 5, 6, 8, 10, 12, 14, 15, 16, 18, 20, 22, 24, 25, 26, 28, 30, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 52, 54, 55, 56, 58, 60, 62, 64, 65, 66, 68, 70, 72, 74, 75, 76, 78, 80, 82, 84, 85, 86, 88, 90, 92, 94, 95, 96, 98, 100]
# [2, 4, 5, 6, 8, 10, 12, 14, 15, 16, 18, 20, 22, 24, 25, 26, 28, 30, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 52, 54, 55, 56, 58, 60, 62, 64, 65, 66, 68, 70, 72, 74, 75, 76, 78, 80, 82, 84, 85, 86, 88, 90, 92, 94, 95, 96, 98, 100]

# %%
"""Q5. Write a program to filter count vowels in the below-given string."""

string = "I want to become a data scientist"

# 
cnt=0
for i in string:
    if(str(i.lower())=="a" or str(i.lower())=="e" or str(i.lower())=="i" or str(i.lower())=="o" or str(i.lower())=="u"):
        cnt+=1
print(cnt)
# Out:
# 12
